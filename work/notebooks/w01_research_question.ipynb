# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I declare a Freestyle lane focused on Automated Enterprise Log Classification and System Anomaly Detection. Rather than standard keyword prioritization, my project addresses the high-risk operational domain of internal network logging. Using structured system metrics alongside unstructured log profile metadata, I intend to prove that lightweight classification models can systematically outperform manual, reactive auditing to catch system drift and infrastructure errors before they escalate into network downtime.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# - Decision: The work directly improves how an Enterprise Infrastructure Manager prioritizes raw, high-volume server errors and anomalous system states.
# - Action: It enables infrastructure teams to instantly route flagged high-risk anomalies into dedicated debugging workflows, replacing manual, repetitive log checking.
# - Cost of a wrong call: A false negative (missing a real anomaly) leads to catastrophic unmitigated network downtime or silent security breaches. A false positive (false alarm) inflicts severe alert fatigue, draining engineering resources and causing teams to ignore the monitoring system entirely.
# - Why ML helps: Human teams cannot manually audit millions of daily log rows. Machine learning extracts structural patterns and boundary correlations across highly skewed datasets to surface real operational anomalies instantly.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import numpy as np
import os

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../..')

file_path = "data/processed/refresh_feature_vector.csv"
df_features = pd.read_csv(file_path)
total_rows = len(df_features)

anomaly_rate = df_features["is_declining_label"].mean()
high_exposure_count = len(df_features[(df_features["impressions_90d"] >= 500) & (df_features["avg_position"] <= 20)])

print(f"--- REAL SNAPSHOT METRICS ---")
print(f"1. Total Log Profile Rows under Analysis: {total_rows:,}")
print(f"2. Baseline Anomaly / Decay Rate (Class Balance): {anomaly_rate:.3%}")
print(f"3. High-Exposure Critical Anomalous Targets (Volume >= 500, Pos <= 20): {high_exposure_count:,}")
# Out:
# --- REAL SNAPSHOT METRICS ---
# 1. Total Log Profile Rows under Analysis: 30,000
# 2. Baseline Anomaly / Decay Rate (Class Balance): 54.207%
# 3. High-Exposure Critical Anomalous Targets (Volume >= 500, Pos <= 20): 12,023

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This project acts strictly as a decision-support system for infrastructure engineering teams; it does not claim to execute autonomous system repairs or offer causal proof of network recovery. All conclusions drawn are purely observational and directional, derived from historical log profiles. It does not predict external changes or guarantee absolute error mitigation, but rather aims to optimize human capacity by converting thousands of unstructured data lines into a safely ranked triage queue.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
