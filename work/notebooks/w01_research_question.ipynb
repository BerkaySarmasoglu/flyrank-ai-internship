# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I declare a Freestyle lane focused on Growth, Recovery, and Momentum Prediction (Organic Traffic Decay & Refresh Prioritization). Rather than standard heuristic keyword optimization, my project addresses the high-risk operational domain of search performance degradation across large content portfolios. Using structured historical time-series performance metrics (GSC/GA4 data), I intend to prove that time-aware classification and momentum prediction models can systematically outperform manual audits in identifying declining content, prioritizing refresh actions, and preventing long-term traffic loss before decay becomes irreversible.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# - Decision: The work directly improves how Content Strategy and Growth Marketing Leads prioritize decay-prone published pages for content refreshes and optimization.
# - Action: It enables SEO/Growth teams to route flagged declining content into an automated review queue for content updates, title/CTR fixes, or technical re-indexing, replacing manual and subjective reporting.
# - Cost of a wrong call: A false negative (missing a genuinely decaying high-value page) leads to compounding organic traffic loss, revenue drops, and loss of SERP positions. A false positive (flagging stable/seasonal pages for refresh) wastes valuable editorial and engineering bandwidth on content that does not require intervention.
# - Why ML helps: Human teams cannot manually track daily ranking fluctuations and click decay across tens or hundreds of thousands of published URLs. Machine learning extracts structural decay patterns, seasonality signals, and CTR-position anomalies to surface high-priority targets automatically.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import numpy as np
import os

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../..')

file_path = "data/processed/refresh_feature_vector.csv"
df_features = pd.read_csv(file_path)
total_rows = len(df_features)

decay_rate = df_features["is_declining_label"].mean()
high_exposure_count = len(df_features[(df_features["impressions_90d"] >= 500) & (df_features["avg_position"] <= 20)])

print("--- REAL SNAPSHOT METRICS ---")
print(f"1. Total Content Pages under Analysis: {total_rows:,}")
print(f"2. Baseline Content Decay Rate (Class Balance): {decay_rate:.3%}")
print(f"3. High-Exposure Priority Targets (Impressions >= 500, Pos <= 20): {high_exposure_count:,}")
# Out:
# --- REAL SNAPSHOT METRICS ---
# 1. Total Content Pages under Analysis: 30,000
# 2. Baseline Content Decay Rate (Class Balance): 54.207%
# 3. High-Exposure Priority Targets (Impressions >= 500, Pos <= 20): 12,023

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project acts strictly as a decision-support system for growth and SEO teams; it does not claim to directly modify live pages, control search engine rankings, or offer causal guarantees of traffic recovery. All conclusions drawn are purely observational and directional, derived from historical GSC and GA4 daily performance metrics. It does not "predict Google's algorithm" or guarantee search engine outcomes, but rather optimizes marketing capacity by organizing high-volume daily performance logs into a safely ranked content action queue.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
